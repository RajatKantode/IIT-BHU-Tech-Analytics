# %% [markdown]
# # FOOD DELIVERY TIME PREDICTION – DEEP LEARNING PROJECT
#
# ---
#
# ## PROJECT OVERVIEW
# This project implements multiple **deep learning regression models** to predict **food delivery time** based on delivery partner attributes, restaurant and customer locations, order details, vehicle type, and computed travel distance.
#
# The objective is to:
# - Accurately estimate delivery duration
# - Identify the most influential factors affecting delivery time
# - Compare deep learning architectures for regression performance
#
# ---
#
# ## DATASET DESCRIPTION
#
# The dataset includes the following information:
#
# - Delivery person details (Age, Ratings, ID)
# - Restaurant latitude & longitude
# - Delivery location latitude & longitude
# - Order type (Snack, Drinks, Buffet, Meal)
# - Vehicle type (Motorcycle, Scooter, Bicycle, Electric Scooter)
# - Time taken for delivery (**target variable**)
#
# ### Data Shape
# - **Initial:** 45,593 rows × 11 columns
# - **After Cleaning & Feature Engineering:** 41,953 rows × 12 columns
#
# ---
#
# ## DATA PREPROCESSING
#
# ### Data Cleaning
# - Removed rows with zero or invalid geographic coordinates
# - Capped delivery person ratings at a maximum value of **5.0**
# - Verified duplicate entries (none found)
#
# ---
#
# ### Feature Engineering
#
# #### Distance Calculation
# - Calculated **great-circle distance** between restaurant and delivery location using the **Haversine formula**
# - Earth radius assumed: **6367 km**
# - Provides realistic travel distance considering Earth’s curvature
#
# #### Feature Scaling
# - Applied **PowerTransformer (Yeo-Johnson method)**
# - Used on:
#   - Delivery_person_Age
#   - Delivery_person_Ratings
#   - Distance
# - Yeo-Johnson supports zero and negative values
# - Improves neural network convergence and stability
#
# ---
#
# ### Train–Test Split
# - **80% Training:** 33,562 samples
# - **20% Testing:** 8,391 samples
# - Stratified split applied on target variable to preserve distribution
#
# ---
#
# ## MODELS IMPLEMENTED
#
# ### 🔹 1. Simple ANN (Artificial Neural Network)
# **Architecture:**
# - Dense(256) → Dropout(0.3) → BatchNorm
# - Dense(64) → Dropout(0.3) → BatchNorm
# - Dense(32) → Dropout(0.3)
# - Dense(1)
#
# **Configuration:**
# - Activation: ReLU (hidden), Linear (output)
# - Optimizer: Adam (LR = 0.01)
# - Loss: Mean Squared Error
# - Epochs: 50 | Batch Size: 64
#
# ---
#
# ### 🔹 2. LSTM (Long Short-Term Memory)
# **Input Reshaping:**
# (samples, timesteps=1, features=3)
#
# **Architecture:**
# - LSTM(128, return_sequences=True)
# - Dropout(0.3) → BatchNorm
# - LSTM(64)
# - Dropout(0.3) → BatchNorm
# - Dense(32, ReLU) → Dropout(0.3)
# - Dense(1)
#
# **Configuration:**
# - Optimizer: Adam (LR = 0.001)
# - Loss: MSE
# - Epochs: 50 | Batch Size: 64
#
# ---
#
# ### 🔹 3. Residual Neural Network (ResNet-style)
# **Architecture:**
# - Input → Dense(256) → BatchNorm → Dropout
# - Residual Block (256 → 256)
# - Residual Block (128 → 128)
# - Dropout → Dense(1)
#
# **Configuration:**
# - Optimizer: Adam (LR = 0.001)
# - Loss: MSE
# - Epochs: 200
# - Early Stopping (Patience = 15)
#
# ---
#
# ## MODEL EVALUATION METRICS
#
# - **R² Score:** Measures variance explained by the model
# - **MSE:** Penalizes large prediction errors
# - **RMSE:** Error in minutes (more interpretable)
#
# ---
#
# ## RESULTS AND ANALYSIS
#
# ### Best Performing Models (Test Set)
#
# | Model        | Test R² | Test RMSE (minutes) |
# |--------------|--------:|--------------------:|
# | **LSTM**     | 0.3636  | 7.48 |
# | Simple ANN  | 0.3338  | 7.65 |
# | Residual NN | 0.3338  | 7.65 |
#
# ---
#
# ### Observations
# - LSTM performed best despite data not being inherently sequential
# - All models showed stable training and validation loss
# - Early stopping successfully reduced overfitting in Residual Network
#
# ---
#
# ## KEY INSIGHTS
#
# - **Driver Quality Matters:** Higher-rated drivers deliver faster
# - **Distance is Crucial:** Delivery time increases with distance
# - **Experience Counts:** Age correlates with delivery efficiency
#
# ---
#
# ## CONCLUSIONS
#
# ### Best Model: **LSTM**
# - Test R² Score: **0.3636**
# - Test RMSE: **7.48 minutes**
# - Most consistent and accurate across datasets
#
# ### Model Performance
# - Average prediction error: **±7.5 minutes**
# - Explains ~36% of delivery time variance
# - Suggests feature saturation with current dataset
#
# ---
#
# ## BUSINESS IMPLICATIONS
#
# - Prioritize high-rated drivers for time-sensitive orders
# - Distance-based delivery time estimation is essential
# - LSTM is recommended for production deployment
#
# ---

# %% [markdown]
# ## Importing Necessary Library

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sklearn
from math import radians, sin, cos, sqrt, asin
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PowerTransformer, MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization ,LSTM,Add,Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error,r2_score

# %%
df = pd.read_excel("/content/Food Delivery Time Prediction Case Study.xlsx")

# %% [markdown]
# ## STEP 1: DATA UNDERSTANDING
#
# Before building any model, it's crucial to understand our data. We'll examine:
# - First few rows to see data structure
# - Shape of dataset
# - Data types and missing values
# - Statistical summary
# - Unique values in each column
#
# This helps us identify:
# - Data quality issues
# - Potential feature engineering opportunities
# - Which columns need preprocessing

# %%
df.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                   37                      4.9
# 1  B379     BANGRES18DEL02                   34                      4.5
# 2  5D6D     BANGRES19DEL01                   23                      4.4
# 3  7A6A    COIMBRES13DEL02                   38                      4.7
# 4  70A2     CHENRES12DEL01                   32                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  Time_taken(min)
# 0                    75.912471        Snack      motorcycle                24
# 1                    77.813237        Snack         scooter                33
# 2                    77.688400       Drinks      motorcycle                26
# 3                    77.026494       Buffet      motorcycle                21
# 4                    80.289982        Snack         scooter                30

# %%
# Check Dataset Shape
df.shape
# Out:
# (45593, 11)

# %%
# Check Data Types and Missing Values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  int64
#  3   Delivery_person_Ratings      45593 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Type_of_order                45593 non-null  object
#  9   Type_of_vehicle              45593 non-null  object
#  10  Time_taken(min)              45593 non-null  int64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 3.8+ MB

# %%
# Statistical Summary
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         45593.000000             45593.000000         45593.000000
# mean             29.544075                 4.632367            17.017729
# std               5.696793                 0.327708             8.185109
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.600000            12.933284
# 50%              29.000000                 4.700000            18.546947
# 75%              34.000000                 4.800000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45593.000000                45593.000000
# mean              70.231332                   17.465186
# std               22.883647                    7.335122
# min              -88.366217                    0.010000
# 25%               73.170000                   12.988453
# 50%               75.898497                   18.633934
# 75%               78.044095                   22.785049
# max               88.433452                   31.054057
#
#        Delivery_location_longitude  Time_taken(min)
# count                 45593.000000     45593.000000
# mean                     70.845702        26.294607
# std                      21.118812         9.383806
# min                       0.010000        10.000000
# 25%                      73.280000        19.000000
# 50%                      76.002574        26.000000
# 75%                      78.107044        32.000000
# max                      88.563452        54.000000

# %%
# Check for Missing Values
df.isna().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Type_of_order                  0
# Type_of_vehicle                0
# Time_taken(min)                0
# dtype: int64

# %%
# Filter Out Invalid Coordinates (0,0)
df = df[
    (df['Restaurant_latitude'] != 0) &
    (df['Restaurant_longitude'] != 0) &
    (df['Delivery_location_latitude'] != 0) &
    (df['Delivery_location_longitude'] != 0)
]
print("shape of column:",df.shape)
# Out:
# shape of column: (41953, 11)

# %%
# Check Duplicates and Unique Values
print("duplicate count:",df.duplicated().sum())
print("\nunique count:\n",df.nunique())
# Out:
# duplicate count: 0
#
# unique count:
#  ID                             41742
# Delivery_person_ID              1170
# Delivery_person_Age               22
# Delivery_person_Ratings           28
# Restaurant_latitude              656
# Restaurant_longitude             517
# Delivery_location_latitude      4362
# Delivery_location_longitude     4362
# Type_of_order                      4
# Type_of_vehicle                    4
# Time_taken(min)                   45
# dtype: int64

# %%
# Cap ratings at a maximum of 5.0 (valid rating range)
print("Count of rating higher than 5:",df[df['Delivery_person_Ratings']>5.0].shape)
df['Delivery_person_Ratings'] = df['Delivery_person_Ratings'].apply(lambda x: 5.0 if x>5.0 else x)
print("shape of column:",df.shape)
# Out:
# Count of rating higher than 5: (46, 11)
# shape of column: (41953, 11)

# %% [markdown]
# ## STEP 2: EXPLORATORY DATA ANALYSIS (EDA)
#
# EDA helps us understand:
# - Relationships between features
# - Distribution of numerical features
# - Presence of outliers
# - Patterns in the data
#
# We'll use:
# - **Correlation matrix** to see feature relationships
# - **Boxplots** to identify outliers
# - **Histograms** to understand distributions

# %%
# Correlation Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# ###  Correlation Analysis Insights
#
# The correlation matrix reveals:
# - **Time_taken(min)** shows moderate correlation with certain features
# - **Age and ratings** might have some relationship
# - **Location coordinates** show expected correlations
#
# This helps us understand which features might be important for prediction.

# %%
plt.figure(figsize=(7,5))
sns.histplot(df['Delivery_person_Age'],kde=True,bins=20,color='blue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Delivery person age')
plt.show()

# %% [markdown]
# ### Delivery Person Age Distribution
#
# The histogram shows:
# - **Age range**: Mostly between 20-40 years
# - **Peak distribution**: Around 25-35 years
# - **Normal-like distribution**: Slightly right-skewed
#
# This indicates a relatively young workforce, typical for delivery services.

# %%
plt.figure(figsize=(7,5))
sns.histplot(df['Delivery_person_Ratings'],kde=True,bins=20,color='blue')
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.title('Distribution of Delivery person Rating')
plt.show()

# %% [markdown]
# ### Delivery Person Ratings Distribution
#
# Key observations:
# - **Most ratings**: Between 4.5-5.0
# - **High performance**: Majority of delivery persons have good ratings
# - **Left-skewed distribution**: Most ratings are high
#
# This suggests:
# - Good quality service
# - Possible rating inflation
# - Need to consider rating as important feature

# %%
print("shape of column:",df.shape)
# Out:
# shape of column: (41953, 11)

# %% [markdown]
# ## STEP 3: DATA PREPROCESSING & FEATURE ENGINEERING
#
# Now we'll create new features and prepare data for modeling:
#
# ### Why Feature Engineering?
#
# 1. **Distance Feature**: Raw coordinates aren't useful - we need actual travel distance
# 4. **Encoding**: Categorical variables need numerical representation
# 5. **Scaling**: Features should be on similar scales for many algorithms

# %%
# Define Haversine Distance Function
def haversine_vectorize(lat1, lon1, lat2, lon2):

    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    newlon = lon2 - lon1
    newlat = lat2 - lat1

    haver_formula = np.sin(newlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(newlon/2.0)**2

    dist = 2 * np.arcsin(np.sqrt(haver_formula ))
    km = 6367 * dist #6367 for distance in KM for miles use 3958
    return km

# %%
dist_cols = ['Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude','Delivery_location_longitude']

# %%
df['Distance'] = df[dist_cols].apply(
    lambda x: haversine_vectorize(x[0], x[1], x[2], x[3]),
    axis=1)
# Out:
# /tmp/ipython-input-2342818139.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda x: haversine_vectorize(x[0], x[1], x[2], x[3]),

# %%
df
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                   37                      4.9
# 1      B379     BANGRES18DEL02                   34                      4.5
# 2      5D6D     BANGRES19DEL01                   23                      4.4
# 3      7A6A    COIMBRES13DEL02                   38                      4.7
# 4      70A2     CHENRES12DEL01                   32                      4.6
# ...     ...                ...                  ...                      ...
# 45587  1178   RANCHIRES16DEL01                   35                      4.2
# 45588  7C09      JAPRES04DEL01                   30                      4.8
# 45590  4F8D     CHENRES08DEL03                   30                      4.9
# 45591  5EEE    COIMBRES11DEL01                   20                      4.7
# 45592  5FB2   RANCHIRES09DEL02                   23                      4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45587            23.371292             85.327872                   23.481292
# 45588            26.902328             75.794257                   26.912328
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude Type_of_order Type_of_vehicle  \
# 0                        75.912471        Snack      motorcycle
# 1                        77.813237        Snack         scooter
# 2                        77.688400       Drinks      motorcycle
# 3                        77.026494       Buffet      motorcycle
# 4                        80.289982        Snack         scooter
# ...                            ...           ...             ...
# 45587                    85.437872       Drinks      motorcycle
# 45588                    75.804257         Meal      motorcycle
# 45590                    80.272439       Drinks         scooter
# 45591                    77.026241        Snack      motorcycle
# 45592                    85.405731        Snack         scooter
#
#        Time_taken(min)   Distance
# 0                   24   3.023250
# 1                   33  20.170858
# 2                   26   1.551783
# 3                   21   7.785510
# 4                   30   6.206239
# ...                ...        ...
# 45587               33  16.589850
# 45588               32   1.488910
# 45590               16   4.654271
# 45591               26   6.228480
# 45592               36  12.066815
#
# [41953 rows x 12 columns]

# %%
df.drop(columns=['ID','Delivery_person_ID','Restaurant_latitude',
'Restaurant_longitude',
'Delivery_location_latitude',
'Delivery_location_longitude','Type_of_order', 'Type_of_vehicle'],axis=1,inplace=True)

# %%
df
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Time_taken(min)  \
# 0                       37                      4.9               24
# 1                       34                      4.5               33
# 2                       23                      4.4               26
# 3                       38                      4.7               21
# 4                       32                      4.6               30
# ...                    ...                      ...              ...
# 45587                   35                      4.2               33
# 45588                   30                      4.8               32
# 45590                   30                      4.9               16
# 45591                   20                      4.7               26
# 45592                   23                      4.9               36
#
#         Distance
# 0       3.023250
# 1      20.170858
# 2       1.551783
# 3       7.785510
# 4       6.206239
# ...          ...
# 45587  16.589850
# 45588   1.488910
# 45590   4.654271
# 45591   6.228480
# 45592  12.066815
#
# [41953 rows x 4 columns]

# %%
df_encoded = df.copy()
df_encoded.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Time_taken(min)   Distance
# 0                   37                      4.9               24   3.023250
# 1                   34                      4.5               33  20.170858
# 2                   23                      4.4               26   1.551783
# 3                   38                      4.7               21   7.785510
# 4                   32                      4.6               30   6.206239

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41953 entries, 0 to 45592
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Delivery_person_Age      41953 non-null  int64
#  1   Delivery_person_Ratings  41953 non-null  float64
#  2   Time_taken(min)          41953 non-null  int64
#  3   Distance                 41953 non-null  float64
# dtypes: float64(2), int64(2)
# memory usage: 1.6 MB

# %%
std_scaler = PowerTransformer(method='yeo-johnson', standardize=True)
scaling_cols = ['Delivery_person_Age',
'Delivery_person_Ratings',
'Distance']
df_encoded[scaling_cols] = std_scaler.fit_transform(df_encoded[scaling_cols])

# %%
X = df_encoded.drop("Time_taken(min)", axis=1)
y = df_encoded["Time_taken(min)"]

# %% [markdown]
# ### Train-Test Split
#
# We split data into:
# - **80% Training** (28,725 samples): For model learning
# - **20% Testing** (7,182 samples): For final evaluation
#
# This split ensures:
# - Enough data for training
# - Unbiased evaluation on unseen data
# - Representative distribution in both sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, train_size=0.8, random_state=123
)

# %%
X_train.shape, X_test.shape
# Out:
# ((33562, 3), (8391, 3))

# %% [markdown]
# ## STEP 4: DEEP LEARNING MODEL BUILDING
#
# We'll implement multiple neural network architectures to find the best performer for delivery time prediction.
#
# ---
#
# ### Why Multiple Deep Learning Architectures?
#
# | Reason | Explanation |
# |--------|-------------|
# | **Different architectures** | Each captures patterns differently (dense vs sequential vs residual) |
# | **No universal best** | Architecture choice depends on data structure |
# | **Regularization techniques** | Dropout, BatchNorm help prevent overfitting |
# | **Comparison** | Helps identify which architecture generalizes best |
#
# ---
#
# ### Models We'll Try
#
# | Model | Type | Description |
# |-------|------|-------------|
# | **Simple ANN** | Feed-Forward Neural Network | Baseline deep learning model with dense layers |
# | **LSTM** | Recurrent Neural Network | Long Short-Term Memory for sequence-like patterns |
# | **Residual NN** | ResNet-Style Network | Skip connections to prevent vanishing gradients |
#
# ---

# %% [markdown]
# 1. Simple ANN

# %%
tf.random.set_seed(42)

model=Sequential()
model.add(Dense(256,activation='relu',input_dim=X_train.shape[1]))
model.add(Dropout(0.3))
model.add(BatchNormalization())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.3))
model.add(BatchNormalization())

model.add(Dense(32,activation='relu'))
model.add(Dropout(0.3))
model.add(BatchNormalization())

model.add(Dense(1,activation='linear'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=['mse']
)

# %%
# Convert boolean columns to int to avoid 'object' dtype issues
X_train = X_train.astype(float)
X_test = X_test.astype(float)

history = model.fit(
    np.array(X_train.values),y_train,
    epochs=50,
    validation_split=0.2,
    batch_size=64
)
# Out:
# Epoch 1/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 279.9127 - mse: 279.9127 - val_loss: 58.1208 - val_mse: 58.1208
# Epoch 2/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 62.8799 - mse: 62.8799 - val_loss: 57.0849 - val_mse: 57.0849
# Epoch 3/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 62.1935 - mse: 62.1935 - val_loss: 56.7533 - val_mse: 56.7533
# Epoch 4/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 61.3420 - mse: 61.3420 - val_loss: 56.2089 - val_mse: 56.2089
# Epoch 5/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.9029 - mse: 60.9029 - val_loss: 56.0193 - val_mse: 56.0193
# Epoch 6/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 61.3275 - mse: 61.3275 - val_loss: 56.0164 - val_mse: 56.0164
# Epoch 7/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.4907 - mse: 60.4907 - val_loss: 55.3589 - val_mse: 55.3589
# Epoch 8/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.5341 - mse: 60.5341 - val_loss: 55.6227 - val_mse: 55.6227
# Epoch 9/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.7231 - mse: 60.7231 - val_loss: 55.7125 - val_mse: 55.7125
# Epoch 10/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.6822 - mse: 60.6822 - val_loss: 56.1558 - val_mse: 56.1558
# Epoch 11/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 60.1496 - mse: 60.1496 - val_loss: 56.2532 - val_mse: 56.2532
# Epoch 12/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.9950 - mse: 59.9950 - val_loss: 55.8045 - val_mse: 55.8045
# Epoch 13/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.3535 - mse: 60.3535 - val_loss: 55.5905 - val_mse: 55.5905
# Epoch 14/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.2502 - mse: 60.2502 - val_loss: 55.5176 - val_mse: 55.5176
# Epoch 15/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.9130 - mse: 59.9130 - val_loss: 55.4184 - val_mse: 55.4184
# Epoch 16/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.1821 - mse: 60.1821 - val_loss: 56.0414 - val_mse: 56.0414
# Epoch 17/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.1423 - mse: 60.1423 - val_loss: 55.5715 - val_mse: 55.5715
# Epoch 18/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 59.7692 - mse: 59.7692 - val_loss: 54.8790 - val_mse: 54.8790
# Epoch 19/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.6256 - mse: 59.6256 - val_loss: 55.6344 - val_mse: 55.6344
# Epoch 20/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 60.1124 - mse: 60.1124 - val_loss: 55.6830 - val_mse: 55.6830
# Epoch 21/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.7376 - mse: 59.7376 - val_loss: 55.1645 - val_mse: 55.1645
# Epoch 22/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.8565 - mse: 59.8565 - val_loss: 55.3142 - val_mse: 55.3142
# Epoch 23/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.8720 - mse: 59.8720 - val_loss: 55.6778 - val_mse: 55.6778
# Epoch 24/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.7789 - mse: 59.7789 - val_loss: 54.7876 - val_mse: 54.7876
# Epoch 25/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 59.5450 - mse: 59.5450 - val_loss: 55.0317 - val_mse: 55.0317
# Epoch 26/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 59.4806 - mse: 59.4806 - val_loss: 55.5337 - val_mse: 55.5337
# Epoch 27/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 59.5033 - mse: 59.5033 - val_loss: 55.2129 - val_mse: 55.2129
# Epoch 28/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.4567 - mse: 59.4567 - val_loss: 55.6816 - val_mse: 55.6816
# Epoch 29/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.5722 - mse: 59.5722 - val_loss: 56.2558 - val_mse: 56.2558
# Epoch 30/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 59.8763 - mse: 59.8763 - val_loss: 54.9427 - val_mse: 54.9427
# Epoch 31/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.4451 - mse: 59.4451 - val_loss: 56.6170 - val_mse: 56.6170
# Epoch 32/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.5991 - mse: 59.5991 - val_loss: 54.8628 - val_mse: 54.8628
# Epoch 33/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.5733 - mse: 59.5733 - val_loss: 54.4556 - val_mse: 54.4556
# Epoch 34/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.3645 - mse: 59.3645 - val_loss: 55.1393 - val_mse: 55.1393
# Epoch 35/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.2754 - mse: 59.2754 - val_loss: 55.5013 - val_mse: 55.5013
# Epoch 36/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.4191 - mse: 59.4191 - val_loss: 55.1776 - val_mse: 55.1776
# Epoch 37/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 59.2097 - mse: 59.2097 - val_loss: 54.7308 - val_mse: 54.7308
# Epoch 38/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 59.1830 - mse: 59.1830 - val_loss: 55.2242 - val_mse: 55.2242
# Epoch 39/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.0107 - mse: 59.0107 - val_loss: 55.0622 - val_mse: 55.0622
# Epoch 40/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.2628 - mse: 59.2628 - val_loss: 55.2917 - val_mse: 55.2917
# Epoch 41/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.5684 - mse: 59.5684 - val_loss: 55.1843 - val_mse: 55.1843
# Epoch 42/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 59.1674 - mse: 59.1674 - val_loss: 55.3404 - val_mse: 55.3404
# Epoch 43/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 59.4666 - mse: 59.4666 - val_loss: 55.1561 - val_mse: 55.1561
# Epoch 44/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 59.2982 - mse: 59.2982 - val_loss: 55.3547 - val_mse: 55.3547
# Epoch 45/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.3244 - mse: 59.3244 - val_loss: 55.4747 - val_mse: 55.4747
# Epoch 46/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 59.2219 - mse: 59.2219 - val_loss: 55.0928 - val_mse: 55.0928
# Epoch 47/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.2866 - mse: 59.2866 - val_loss: 54.8250 - val_mse: 54.8250
# Epoch 48/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 58.9946 - mse: 58.9946 - val_loss: 54.9318 - val_mse: 54.9318
# Epoch 49/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.3310 - mse: 59.3310 - val_loss: 55.2339 - val_mse: 55.2339
# Epoch 50/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.1860 - mse: 59.1860 - val_loss: 57.6327 - val_mse: 57.6327

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['mse'], label='Training mse')
plt.plot(history.history['val_mse'],  label='Validation mse')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
y_pred_test = model.predict(np.array(X_test.values))
R2 = r2_score(y_test, y_pred_test)
acc=model.evaluate(np.array(X_test.values),y_test)
mse_test_lr = mean_squared_error(y_test, y_pred_test)
rmse_test_lr = mse_test_lr**0.5



print("R2 =",R2 )
print('-'*60)
print("MSE =",acc)
print("-"*60)
print("MSE for test:", mse_test_lr)
print("-"*60)
print("RMSE for test:", rmse_test_lr)
# Out:
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 58.1735 - mse: 58.1735
# R2 = 0.3337893486022949
# ------------------------------------------------------------
# MSE = [58.568946838378906, 58.568946838378906]
# ------------------------------------------------------------
# MSE for test: 58.56893539428711
# ------------------------------------------------------------
# RMSE for test: 7.653034391291281

# %% [markdown]
# 2. LSTM

# %%
tf.random.set_seed(42)

# Convert to float
X_train = X_train.astype(float)
X_test = X_test.astype(float)

# Resahpe Because Data is not sequential
X_train_reshaped = np.reshape(X_train.values, (X_train.shape[0], 1, X_train.shape[1]))
X_test_reshaped  = np.reshape(X_test.values,  (X_test.shape[0], 1, X_test.shape[1]))

model2 = Sequential()
model2.add(LSTM(128, return_sequences=True, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
model2.add(Dropout(0.3))
model2.add(BatchNormalization())
model2.add(LSTM(64, return_sequences=False))
model2.add(Dropout(0.3))
model2.add(BatchNormalization())
model2.add(Dense(32, activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(1, activation='linear'))
model2.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mse']
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history2 = model2.fit(
    X_train_reshaped,
    y_train,
    epochs=50,
    validation_split=0.2,
    batch_size=64
)
# Out:
# Epoch 1/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 385.1772 - mse: 385.1772 - val_loss: 75.9747 - val_mse: 75.9747
# Epoch 2/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 107.9605 - mse: 107.9605 - val_loss: 60.2341 - val_mse: 60.2341
# Epoch 3/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 99.8614 - mse: 99.8614 - val_loss: 60.1719 - val_mse: 60.1719
# Epoch 4/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 97.3515 - mse: 97.3515 - val_loss: 60.3118 - val_mse: 60.3118
# Epoch 5/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 92.3441 - mse: 92.3441 - val_loss: 59.0646 - val_mse: 59.0646
# Epoch 6/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 89.3396 - mse: 89.3396 - val_loss: 58.9083 - val_mse: 58.9083
# Epoch 7/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 87.4349 - mse: 87.4349 - val_loss: 58.5674 - val_mse: 58.5674
# Epoch 8/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 85.4009 - mse: 85.4009 - val_loss: 58.0087 - val_mse: 58.0087
# Epoch 9/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 82.7372 - mse: 82.7372 - val_loss: 57.5182 - val_mse: 57.5182
# Epoch 10/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 79.7860 - mse: 79.7860 - val_loss: 57.7727 - val_mse: 57.7727
# Epoch 11/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 79.4738 - mse: 79.4738 - val_loss: 58.2512 - val_mse: 58.2512
# Epoch 12/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 78.3545 - mse: 78.3545 - val_loss: 57.1933 - val_mse: 57.1933
# Epoch 13/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 77.9529 - mse: 77.9529 - val_loss: 57.5784 - val_mse: 57.5784
# Epoch 14/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 75.7803 - mse: 75.7803 - val_loss: 57.0916 - val_mse: 57.0916
# Epoch 15/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 75.2154 - mse: 75.2154 - val_loss: 56.5902 - val_mse: 56.5902
# Epoch 16/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 75.0204 - mse: 75.0204 - val_loss: 56.6160 - val_mse: 56.6160
# Epoch 17/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 74.9536 - mse: 74.9536 - val_loss: 56.1350 - val_mse: 56.1350
# Epoch 18/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 72.8274 - mse: 72.8274 - val_loss: 56.2505 - val_mse: 56.2505
# Epoch 19/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 73.6857 - mse: 73.6857 - val_loss: 56.1098 - val_mse: 56.1098
# Epoch 20/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 73.0627 - mse: 73.0627 - val_loss: 55.5981 - val_mse: 55.5981
# Epoch 21/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 72.0989 - mse: 72.0989 - val_loss: 55.9573 - val_mse: 55.9573
# Epoch 22/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 72.7210 - mse: 72.7210 - val_loss: 55.7206 - val_mse: 55.7206
# Epoch 23/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 71.6561 - mse: 71.6561 - val_loss: 55.5915 - val_mse: 55.5915
# Epoch 24/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 72.0433 - mse: 72.0433 - val_loss: 55.3288 - val_mse: 55.3288
# Epoch 25/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 70.3003 - mse: 70.3003 - val_loss: 55.1272 - val_mse: 55.1272
# Epoch 26/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 71.3617 - mse: 71.3617 - val_loss: 55.5918 - val_mse: 55.5918
# Epoch 27/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 71.2348 - mse: 71.2348 - val_loss: 55.0448 - val_mse: 55.0448
# Epoch 28/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 69.7772 - mse: 69.7772 - val_loss: 55.0881 - val_mse: 55.0881
# Epoch 29/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 70.1364 - mse: 70.1364 - val_loss: 55.1016 - val_mse: 55.1016
# Epoch 30/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 69.2399 - mse: 69.2399 - val_loss: 55.0740 - val_mse: 55.0740
# Epoch 31/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 69.7155 - mse: 69.7155 - val_loss: 55.0086 - val_mse: 55.0086
# Epoch 32/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 69.3193 - mse: 69.3193 - val_loss: 55.2063 - val_mse: 55.2063
# Epoch 33/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 69.6882 - mse: 69.6882 - val_loss: 54.9689 - val_mse: 54.9689
# Epoch 34/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 69.1050 - mse: 69.1050 - val_loss: 55.1096 - val_mse: 55.1096
# Epoch 35/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 69.1678 - mse: 69.1678 - val_loss: 55.1424 - val_mse: 55.1424
# Epoch 36/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 68.0693 - mse: 68.0693 - val_loss: 55.0474 - val_mse: 55.0474
# Epoch 37/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 68.9942 - mse: 68.9942 - val_loss: 54.8678 - val_mse: 54.8678
# Epoch 38/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 68.6007 - mse: 68.6007 - val_loss: 54.9162 - val_mse: 54.9162
# Epoch 39/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 68.0543 - mse: 68.0543 - val_loss: 54.7833 - val_mse: 54.7833
# Epoch 40/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 66.8989 - mse: 66.8989 - val_loss: 55.0134 - val_mse: 55.0134
# Epoch 41/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 66.8845 - mse: 66.8845 - val_loss: 54.6997 - val_mse: 54.6997
# Epoch 42/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 67.3090 - mse: 67.3090 - val_loss: 54.8900 - val_mse: 54.8900
# Epoch 43/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 67.2119 - mse: 67.2119 - val_loss: 54.6332 - val_mse: 54.6332
# Epoch 44/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 67.3061 - mse: 67.3061 - val_loss: 54.8605 - val_mse: 54.8605
# Epoch 45/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 66.5334 - mse: 66.5334 - val_loss: 54.7700 - val_mse: 54.7700
# Epoch 46/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 67.3453 - mse: 67.3453 - val_loss: 54.7607 - val_mse: 54.7607
# Epoch 47/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 67.1100 - mse: 67.1100 - val_loss: 54.6333 - val_mse: 54.6333
# Epoch 48/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 66.6448 - mse: 66.6448 - val_loss: 54.7056 - val_mse: 54.7056
# Epoch 49/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 66.2175 - mse: 66.2175 - val_loss: 54.7099 - val_mse: 54.7099
# Epoch 50/50
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 66.4785 - mse: 66.4785 - val_loss: 54.5079 - val_mse: 54.5079

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(history2.history['mse'], label='Training mse')
plt.plot(history2.history['val_mse'],  label='Validation mse')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history2.history['loss'], label='Training Loss')
plt.plot(history2.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
X_test_reshaped = np.reshape(X_test.values, (X_test.shape[0], 1, X_test.shape[1]))
y_pred_test = model2.predict(X_test_reshaped)

R2 = r2_score(y_test, y_pred_test)
loss, mse = model2.evaluate(X_test_reshaped, y_test)
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)

print("R2 =", R2)
print('-'*60)
print("Loss =", loss)
print('-'*60)
print("MSE (from model.evaluate) =", mse)
print("-"*60)
print("MSE (manual) =", mse_test)
print("-"*60)
print("RMSE =", rmse_test)
# Out:
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 55.3844 - mse: 55.3844
# R2 = 0.3636026978492737
# ------------------------------------------------------------
# Loss = 55.947959899902344
# ------------------------------------------------------------
# MSE (from model.evaluate) = 55.947959899902344
# ------------------------------------------------------------
# MSE (manual) = 55.947940826416016
# ------------------------------------------------------------
# RMSE = 7.479835614932725

# %% [markdown]
# 3. Residual NN

# %%
tf.random.set_seed(42)


input_layer = Input(shape=(X_train.shape[1],))

# First block
x = Dense(256, activation='relu')(input_layer)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)

# Residual Block 1
res = Dense(256, activation='relu')(x)
res = BatchNormalization()(res)
res = Dense(256)(res)
x = Add()([x, res])
x = tf.keras.activations.relu(x)

# Residual Block 2
res = Dense(128, activation='relu')(x)
res = BatchNormalization()(res)
res = Dense(128)(res)

# Match dimensions before addition
x = Dense(128)(x)
x = Add()([x, res])
x = tf.keras.activations.relu(x)

x = Dropout(0.3)(x)

output = Dense(1, activation='linear')(x)

model3 = Model(inputs=input_layer, outputs=output)

model3.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mse']
)

# %%
early_stop = EarlyStopping(patience=15, restore_best_weights=True)
history3 = model3.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=64,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 120.6061 - mse: 120.6061 - val_loss: 61.4140 - val_mse: 61.4140
# Epoch 2/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 69.4817 - mse: 69.4817 - val_loss: 59.0964 - val_mse: 59.0964
# Epoch 3/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 67.7360 - mse: 67.7360 - val_loss: 57.9275 - val_mse: 57.9275
# Epoch 4/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 67.3445 - mse: 67.3445 - val_loss: 57.5357 - val_mse: 57.5357
# Epoch 5/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 66.0736 - mse: 66.0736 - val_loss: 56.4375 - val_mse: 56.4375
# Epoch 6/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 64.8079 - mse: 64.8079 - val_loss: 56.2672 - val_mse: 56.2672
# Epoch 7/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 64.9622 - mse: 64.9622 - val_loss: 55.7566 - val_mse: 55.7566
# Epoch 8/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 64.7317 - mse: 64.7317 - val_loss: 55.6427 - val_mse: 55.6427
# Epoch 9/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 64.4183 - mse: 64.4183 - val_loss: 55.5024 - val_mse: 55.5024
# Epoch 10/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 63.7166 - mse: 63.7166 - val_loss: 55.7675 - val_mse: 55.7675
# Epoch 11/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 63.2978 - mse: 63.2978 - val_loss: 55.3028 - val_mse: 55.3028
# Epoch 12/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 63.0273 - mse: 63.0273 - val_loss: 54.9907 - val_mse: 54.9907
# Epoch 13/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 62.4199 - mse: 62.4199 - val_loss: 55.0327 - val_mse: 55.0327
# Epoch 14/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 62.4417 - mse: 62.4417 - val_loss: 55.1976 - val_mse: 55.1976
# Epoch 15/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 62.8657 - mse: 62.8657 - val_loss: 55.2052 - val_mse: 55.2052
# Epoch 16/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 62.8340 - mse: 62.8340 - val_loss: 54.9476 - val_mse: 54.9476
# Epoch 17/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 62.5082 - mse: 62.5082 - val_loss: 55.0356 - val_mse: 55.0356
# Epoch 18/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 61.9747 - mse: 61.9747 - val_loss: 55.0003 - val_mse: 55.0003
# Epoch 19/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 61.7410 - mse: 61.7410 - val_loss: 54.7994 - val_mse: 54.7994
# Epoch 20/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 62.1720 - mse: 62.1720 - val_loss: 54.7761 - val_mse: 54.7761
# Epoch 21/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 62.0545 - mse: 62.0545 - val_loss: 54.7316 - val_mse: 54.7316
# Epoch 22/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 62.2036 - mse: 62.2036 - val_loss: 54.5225 - val_mse: 54.5225
# Epoch 23/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 62.1244 - mse: 62.1244 - val_loss: 54.4053 - val_mse: 54.4053
# Epoch 24/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 61.2572 - mse: 61.2572 - val_loss: 54.6308 - val_mse: 54.6308
# Epoch 25/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 61.9451 - mse: 61.9451 - val_loss: 54.5395 - val_mse: 54.5395
# Epoch 26/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 61.9290 - mse: 61.9290 - val_loss: 54.4779 - val_mse: 54.4779
# Epoch 27/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 61.0587 - mse: 61.0587 - val_loss: 54.5854 - val_mse: 54.5854
# Epoch 28/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 60.9861 - mse: 60.9861 - val_loss: 54.5716 - val_mse: 54.5716
# Epoch 29/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 61.5139 - mse: 61.5139 - val_loss: 54.6670 - val_mse: 54.6670
# Epoch 30/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 61.3130 - mse: 61.3130 - val_loss: 54.5567 - val_mse: 54.5567
# Epoch 31/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 60.8807 - mse: 60.8807 - val_loss: 54.4060 - val_mse: 54.4060
# Epoch 32/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 61.0041 - mse: 61.0041 - val_loss: 54.2333 - val_mse: 54.2333
# Epoch 33/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 60.4098 - mse: 60.4098 - val_loss: 54.5798 - val_mse: 54.5798
# Epoch 34/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 60.9035 - mse: 60.9035 - val_loss: 54.2442 - val_mse: 54.2442
# Epoch 35/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 60.6056 - mse: 60.6056 - val_loss: 54.1624 - val_mse: 54.1624
# Epoch 36/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 60.3984 - mse: 60.3984 - val_loss: 54.2484 - val_mse: 54.2484
# Epoch 37/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 60.4263 - mse: 60.4263 - val_loss: 54.2880 - val_mse: 54.2880
# Epoch 38/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 60.1576 - mse: 60.1576 - val_loss: 54.4294 - val_mse: 54.4294
# Epoch 39/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 60.6289 - mse: 60.6289 - val_loss: 54.2207 - val_mse: 54.2207
# Epoch 40/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 60.4222 - mse: 60.4222 - val_loss: 54.1935 - val_mse: 54.1935
# Epoch 41/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 59.7423 - mse: 59.7423 - val_loss: 54.1714 - val_mse: 54.1714
# Epoch 42/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 59.7512 - mse: 59.7512 - val_loss: 54.5582 - val_mse: 54.5582
# Epoch 43/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 59.9102 - mse: 59.9102 - val_loss: 54.3021 - val_mse: 54.3021
# Epoch 44/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 59.6709 - mse: 59.6709 - val_loss: 54.4767 - val_mse: 54.4767
# Epoch 45/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 59.9492 - mse: 59.9492 - val_loss: 54.4711 - val_mse: 54.4711
# Epoch 46/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 60.2155 - mse: 60.2155 - val_loss: 54.2566 - val_mse: 54.2566
# Epoch 47/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 60.2540 - mse: 60.2540 - val_loss: 54.2007 - val_mse: 54.2007
# Epoch 48/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 60.2657 - mse: 60.2657 - val_loss: 54.5637 - val_mse: 54.5637
# Epoch 49/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 60.3366 - mse: 60.3366 - val_loss: 54.4367 - val_mse: 54.4367
# Epoch 50/200
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 59.9166 - mse: 59.9166 - val_loss: 54.2198 - val_mse: 54.2198

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(history3.history['mse'], label='Training mse')
plt.plot(history3.history['val_mse'],  label='Validation mse')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history3.history['loss'], label='Training Loss')
plt.plot(history3.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
y_pred_test = model.predict(X_test)
y_pred_test = y_pred_test.flatten()



R2 = r2_score(y_test, y_pred_test)
loss, mse = model.evaluate(X_test, y_test, verbose=0)
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)


print("R2 =", R2)
print('-'*60)
print("Loss =", loss)
print('-'*60)
print("MSE (from model.evaluate) =", mse)
print("-"*60)
print("MSE (manual) =", mse_test)
print("-"*60)
print("RMSE =", rmse_test)
# Out:
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R2 = 0.3337893486022949
# ------------------------------------------------------------
# Loss = 58.568946838378906
# ------------------------------------------------------------
# MSE (from model.evaluate) = 58.568946838378906
# ------------------------------------------------------------
# MSE (manual) = 58.56893539428711
# ------------------------------------------------------------
# RMSE = 7.653034391291281
